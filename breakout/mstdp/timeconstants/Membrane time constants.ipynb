# %% [markdown]
# ## Installation

# %%
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# Out:
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.2.4 is available.
# You should consider upgrading via the '/usr/local/Cellar/jupyterlab/3.0.14/libexec/bin/python3.9 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.2.4 is available.
# You should consider upgrading via the '/usr/local/Cellar/jupyterlab/3.0.14/libexec/bin/python3.9 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# ...
#      |████████████████████████████████| 7.2 MB 5.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 61 kB 836 kB/s  eta 0:00:01
# ...
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# ...
#      |████████████████████████████████| 3.0 MB 25.7 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.2.4 is available.
# ...

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## NeuroElectro dataset
#
# Let's take a look at the [NeuroElectro dataset](https://neuroelectro.org/api/docs/).

# %%
data = pd.read_csv('./article_ephys_metadata_curated.csv', sep="	")
data.head()
# Out:
#    Index                                              Title      Pmid  \
# 0    150  Cell type-specific effects of adenosine on cor...  24108800
# 1    149  Cell type-specific effects of adenosine on cor...  24108800
# 2    151  Cell type-specific effects of adenosine on cor...  24108800
# 3    152  Cell type-specific effects of adenosine on cor...  24108800
# 4     88  Age-related changes to layer 3 pyramidal cells...  24323499
#
#    PubYear   LastAuthor  ArticleID  TableID  \
# 0     2015  Feldmeyer D      88449  35984.0
# 1     2015  Feldmeyer D      88449  35984.0
# 2     2015  Feldmeyer D      88449  35984.0
# 3     2015  Feldmeyer D      88449  35984.0
# 4     2015     Peters A      88469  36033.0
#
#                            NeuronName  \
# 0               Neocortex basket cell
# 1           Neocortex Martinotti cell
# 2               Neocortex basket cell
# 3          Neocortex interneuron deep
# 4  Neocortex pyramidal cell layer 2-3
#
# ...

# %% [markdown]
# Now let's plot the tau distribution.

# %%
distribution = data["tau"].dropna()
distribution = distribution.to_numpy()

_ = plt.hist(distribution, bins='auto')
plt.title("Distribution of membrane time constants in the brain")
plt.xlabel("Time constant (ms)")
plt.show()
